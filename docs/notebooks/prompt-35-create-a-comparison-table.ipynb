# %% [markdown]
# # Prompt 35: Create a comparison table
#
# Portable SecuredMe Education starter notebook.

# %% [markdown]
# ## Prompt
#
# ```text
# Make a table comparing input, action, result, and learning value. Use simple words, show the expected result, and finish with one next action.
#
# Topic: replace with your topic
# Audience: replace with your audience
# Result wanted: replace with the result you want
# ```

# %% [markdown]
# ## Expected Result
#
# A clear beginner-friendly output that can be used right away.

# %% [markdown]
# ## Execution Checklist
#
# - [ ] Choose one topic.
# - [ ] Name the audience.
# - [ ] Say what result you want.
# - [ ] Use the prompt.
# - [ ] Keep the useful part.
# - [ ] Choose one next action.

# %% [markdown]
# ## Result Capture
#
# Status:
#
# Useful result:
#
# What improved:
#
# Next small step:

# %% [markdown]
# ## Public Learning Reminder
#
# Use classroom-safe examples. Keep personal account details and private class records out of the notebook.

# %% [markdown]
# ## What The User Learns
#
# Make a table comparing input, action, result, and learning value.

# %% [markdown]
# ## Next Fabrication Step
#
# Save the best part and try one small improvement.
